# %%
print('hello')
# Out:
# hello

# %%
print(type(12))
x= str(12)
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
number= 30
w= "your score is" + str(30)
print(w)
# Out:
# your score is30

# %%
n= 25
w= int(25)
print(w+5)
# Out:
# 30

# %%
n= input("Enter number")
# Out:
# Enter number 8

# %%
print(type(n))
# Out:
# <class 'str'>

# %%
n=int(input("Enter number"))

if n % 2 !=1 :
    print("Even")
else:
    print("Odd")
# Out:
# Enter number 55
# Odd

# %%
w= input("Enter number")
print(type(w))
# Out:
# Enter number 5
# <class 'str'>

# %%
w= int(input("34"))
print(type(w))
# Out:
# 34 8
# <class 'int'>

# %%
x= 10
y= 9
z= 11
print(y>x)
# Out:
# False

# %%
print(y<x or x>y)
# Out:
# True

# %%
print(y<x and x>y)
# Out:
# True

# %%
print(y<x or x<y)
# Out:
# True

# %%
print(y>x or x<y)
# Out:
# False

# %%
print(y<x and x>y)
# Out:
# True

# %%
x= 20
x+= 5
print(x)
# Out:
# 25

# %%
x= [2,4,5,6,7,8]
print(3 in x)
print(4 not in x)
# Out:
# False
# False

# %%
print(10, 20, 30,sep=',')
# Out:
# 10,20,30

# %%
weather= "Rainy"
if weather != "Sunny":
    print("Its a beautiful day")
else:
    print("It's a chilly day")
# Out:
# Its a beautiful day

# %%
todolist= ["Study", "Exercise","Read"]
for task in todolist:
    print("I need to:", task)
# Out:
# I need to: Study
# I need to: Exercise
# I need to: Read

# %%
numbers= [1,2,3,4,5]
for i in numbers:
    if i%2==1:
        print(f"odd {i}")
    else:
        print(f"even {i}")
# Out:
# odd 1
# even 2
# odd 3
# even 4
# odd 5

# %%
n= 10
w= 5
if n>w:
    print("This is correct")
elif n% w== 0:
    print("True")
else:
    print("false")
# Out:
# This is correct

# %%
age= 78
if age< 18:
    print("You're not eligible for a discount")
elif age >=18 and age <= 30:
    print("You are eligible for a 10% discount")
else:
    print("You're eligible for a 20% discount")
# Out:
# You're eligible for a 20% discount

# %%
for item in range(1,9,2):
    print(item)
# Out:
# 1
# 3
# 5
# 7

# %%
for item in range(9):
    print(item)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
number= 0
for num in range(11):
    number= num+2
    print(f' sum of number when 2 is added: {number}')
    print(num)
# Out:
#  sum of number when 2 is added: 2
# 0
#  sum of number when 2 is added: 3
# 1
#  sum of number when 2 is added: 4
# 2
#  sum of number when 2 is added: 5
# 3
#  sum of number when 2 is added: 6
# 4
#  sum of number when 2 is added: 7
# 5
#  sum of number when 2 is added: 8
# 6
#  sum of number when 2 is added: 9
# 7
#  sum of number when 2 is added: 10
# 8
#  sum of number when 2 is added: 11
# 9
#  sum of number when 2 is added: 12
# 10

# %%
n= [1,2,3,4]
n.append(40) #Add to the end of the list
print(n)
# Out:
# [1, 2, 3, 4, 40]

# %%
a= [1,2,10,4,15,6,7]
input()
# Out:
#  2
# '2'

# %%
n= input("Enter number")
a= [1,2,3,4,10,12]

if n in a:
    print(n)
else:
    print('not in the list')
# Out:
# Enter number 2
# not in the list

# %%
a= [1,2,3,4,5,7,8,9,10]
i= int(input('Enter number'))
for number in a:
    if i not in a:
        print(f'{i} is not in the list')
        break
else:
    print(f'{i} is in the list')
# Out:
# Enter number 20
# 20 is not in the list

# %% [markdown]
# print(i)

# %%
print(type(i))
# Out:
# <class 'str'>

# %%
i/2
# Out:
# 10.0

# %%
age= int(input("Enter your age:"))
if age >= 18:
    print("You're old enough to learn to drive")
else:
    remainingyears = 18 - age
    print("You need",remainingyears, "more years to learn to drive")
# Out:
# Enter your age: 15
# You need 3 more years to learn to drive

# %%
myage= 29
n= int(input("Enter your age:"))
if n==myage:
    print("We're of the same age")
elif n<myage:
    yearsyounger= myage-n
    print("You're",yearsyounger, "years younger than me")
else:
    yearsolder= n-myage
    print("You're", yearsolder, "years older than me")
# Out:
# Enter your age: 50
# You're 21 years older than me

# %%
a= int(input("Enter first number:"))
b= int(input("Enter second number:"))
if a>b:
    print(a,"is greater than", b)
elif a<b:
    print(a, "is smaller than", b)
else:
    a==b
    print(a, "is equal to", b)
# Out:
# Enter first number: 5
# Enter second number: 15
# 5 is smaller than 15

# %%
score= int(input("Enter your score (0-100):"))
if score <=100 and score >=90:
    print("A")
elif score <=89 and score >=80:
    print("B")
elif score <=79 and score >=70:
    print("C")
elif score <=69 and score >=60:
    print("D")
else:
    print("F")
# Out:
# Enter your score (0-100): 12
# F

# %%
n= input("Enter a month in full name:")
if n in ["September", "October", "November"]:
    print("Season is Autumn")
elif n in ["December", "January", "February"]:
    print("Season is Winter")
elif n in ["March", "May", "April"]:
    print("Season is Spring")
else:
    print("Season is Summer")
# Out:
# Enter a month in full name: August
# Season is Summer

# %%
name = input("Enter your name: ")

if name != "Jerry":
    portions = int(input("Enter number of portions: "))
    priceperportion = 5.90
    total_cost = portions * priceperportion
    
    print(f"The total cost is {total_cost}")
# Out:
# Enter your name:  Debby
# Enter number of portions:  12
# The total cost is 70.80000000000001

# %%
count= 6
while count >0:
    print(count)
    #count= count- 1
    count-=1
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
import random
a= random.randint(2,10)
print(a)
# Out:
# 7

# %%
import math
b= math.sqrt(9)
print(b)

# %%
# if we guess a number greater than number print('Too low try again') & vice versa
import random
a= random.randint(1,100)
n= int(input('Enter a number:'))
while n>a:
    print("Too low try again")
# Out:
# Enter a number: 90
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# Too low try again
# ...

# %%
# if we guess a number greater than number print('Too low try again') & vice versa
import random
a= random.randint(1, 100)
n= 0
#n= int(input('Enter a number:'))
while n!= a:
    n= int(input('Enter a number:'))
    if n<a:
        print('Too low try again')
    elif n>a:
        print('Too high try again')

print(f'number is correct{a}')
# Out:
# Enter a number: 50
# Too high try again
# Enter a number: 30
# Too high try again
# Enter a number: 2
# Too low try again
# Enter a number: 10
# Too low try again
# Enter a number: 15
# Too high try again
# Enter a number: 12
# number is correct12

# %%
secret_word = "python"
tries = 3
while tries > 0:
    guess = input("Guess the secret word: ")
    if guess == secret_word:
        print("You win")
        break
    else:
        tries= tries-1
        print("Wrong, try again")
print("Game over")
# Out:
# Guess the secret word:  python
# You win
# Game over
