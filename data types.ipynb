# %%
print('hello')
# Out:
# hello

# %%
print(type(12))
x= str(12)
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
number= 30
w= "your score is" + str(30)
print(w)
# Out:
# your score is30

# %%
n= 25
w= int(25)
print(w+5)
# Out:
# 30

# %%
n= input("Enter number")
# Out:
# Enter number 8

# %%
print(type(n))
# Out:
# <class 'str'>

# %%
n=int(input("Enter number"))

if n % 2 ==1 :
    print("Odd")
else:
    print("Even")
# Out:
# Enter number 30
# Even

# %%
w= input("Enter number")
print(type(w))
# Out:
# Enter number 5
# <class 'str'>

# %%
w= int(input("34"))
print(type(w))
# Out:
# 34 8
# <class 'int'>
